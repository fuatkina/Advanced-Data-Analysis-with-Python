# %% [markdown]
# ## Scrapy - Extracting movie data from imdb
#
#
# While preparing codes in this page, I have utilized following source: https://app.datacamp.com/learn/courses/web-scraping-with-python

# %%
#pip install scrapy

# %%
# Import a scrapy Selector
from scrapy import Selector

# Import requests
import requests

url = 'https://m.imdb.com/chart/top'

# Create the string html containing the HTML source
html = requests.get(url).content

# Create the Selector object sel from html
sel = Selector(text = html)

# Print out the number of elements in the HTML document
print( "You have found: ", len(sel.xpath('//*')))
# Out:
# 2022-08-25 16:57:50 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:57:51 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /chart/top HTTP/1.1" 200 None
# You have found:  4317

# %%
type(html)
# Out:
# bytes

# %%
type(sel)
# Out:
# scrapy.selector.unified.Selector

# %%
xpath_for_movienames ='//h4'

# %%
sel.xpath(xpath_for_movienames).extract()
# Out:
# ['<h4>\n<span class="unbold">1.</span>\nThe Shawshank Redemption\n<span class="unbold">(1994)</span>\n</h4>',
#  '<h4>\n<span class="unbold">2.</span>\nThe Godfather\n<span class="unbold">(1972)</span>\n</h4>',
#  '<h4>\n<span class="unbold">3.</span>\nThe Dark Knight\n<span class="unbold">(2008)</span>\n</h4>',
#  '<h4>\n<span class="unbold">4.</span>\nThe Godfather Part II\n<span class="unbold">(1974)</span>\n</h4>',
#  '<h4>\n<span class="unbold">5.</span>\n12 Angry Men\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">6.</span>\nSchindler\'s List\n<span class="unbold">(1993)</span>\n</h4>',
#  '<h4>\n<span class="unbold">7.</span>\nThe Lord of the Rings: The Return of the King\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">8.</span>\nPulp Fiction\n<span class="unbold">(1994)</span>\n</h4>',
#  '<h4>\n<span class="unbold">9.</span>\nThe Lord of the Rings: The Fellowship of the Ring\n<span class="unbold">(2001)</span>\n</h4>',
#  '<h4>\n<span class="unbold">10.</span>\nThe Good, the Bad and the Ugly\n<span class="unbold">(1966)</span>\n</h4>',
#  '<h4>\n<span class="unbold">11.</span>\nForrest Gump\n<span class="unbold">(1994)</span>\n</h4>',
#  '<h4>\n<span class="unbold">12.</span>\nFight Club\n<span class="unbold">(1999)</span>\n</h4>',
#  '<h4>\n<span class="unbold">13.</span>\nInception\n<span class="unbold">(2010)</span>\n</h4>',
#  '<h4>\n<span class="unbold">14.</span>\nThe Lord of the Rings: The Two Towers\n<span class="unbold">(2002)</span>\n</h4>',
#  '<h4>\n<span class="unbold">15.</span>\nStar Wars: Episode V - The Empire Strikes Back\n<span class="unbold">(1980)</span>\n</h4>',
#  '<h4>\n<span class="unbold">16.</span>\nThe Matrix\n<span class="unbold">(1999)</span>\n</h4>',
#  '<h4>\n<span class="unbold">17.</span>\nGoodfellas\n<span class="unbold">(1990)</span>\n</h4>',
#  '<h4>\n<span class="unbold">18.</span>\nOne Flew Over the Cuckoo\'s Nest\n<span class="unbold">(1975)</span>\n</h4>',
#  '<h4>\n<span class="unbold">19.</span>\nSe7en\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">20.</span>\nSeven Samurai\n<span class="unbold">(1954)</span>\n</h4>',
#  '<h4>\n<span class="unbold">21.</span>\nIt\'s a Wonderful Life\n<span class="unbold">(1946)</span>\n</h4>',
#  '<h4>\n<span class="unbold">22.</span>\nThe Silence of the Lambs\n<span class="unbold">(1991)</span>\n</h4>',
#  '<h4>\n<span class="unbold">23.</span>\nCity of God\n<span class="unbold">(2002)</span>\n</h4>',
#  '<h4>\n<span class="unbold">24.</span>\nSaving Private Ryan\n<span class="unbold">(1998)</span>\n</h4>',
#  '<h4>\n<span class="unbold">25.</span>\nLife Is Beautiful\n<span class="unbold">(1997)</span>\n</h4>',
#  '<h4>\n<span class="unbold">26.</span>\nThe Green Mile\n<span class="unbold">(1999)</span>\n</h4>',
#  '<h4>\n<span class="unbold">27.</span>\nInterstellar\n<span class="unbold">(2014)</span>\n</h4>',
#  '<h4>\n<span class="unbold">28.</span>\nStar Wars\n<span class="unbold">(1977)</span>\n</h4>',
#  '<h4>\n<span class="unbold">29.</span>\nTerminator 2: Judgment Day\n<span class="unbold">(1991)</span>\n</h4>',
#  '<h4>\n<span class="unbold">30.</span>\nBack to the Future\n<span class="unbold">(1985)</span>\n</h4>',
#  '<h4>\n<span class="unbold">31.</span>\nSpirited Away\n<span class="unbold">(2001)</span>\n</h4>',
#  '<h4>\n<span class="unbold">32.</span>\nPsycho\n<span class="unbold">(1960)</span>\n</h4>',
#  '<h4>\n<span class="unbold">33.</span>\nThe Pianist\n<span class="unbold">(2002)</span>\n</h4>',
#  '<h4>\n<span class="unbold">34.</span>\nLéon: The Professional\n<span class="unbold">(1994)</span>\n</h4>',
#  '<h4>\n<span class="unbold">35.</span>\nParasite\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">36.</span>\nThe Lion King\n<span class="unbold">(1994)</span>\n</h4>',
#  '<h4>\n<span class="unbold">37.</span>\nGladiator\n<span class="unbold">(2000)</span>\n</h4>',
#  '<h4>\n<span class="unbold">38.</span>\nAmerican History X\n<span class="unbold">(1998)</span>\n</h4>',
#  '<h4>\n<span class="unbold">39.</span>\nThe Departed\n<span class="unbold">(2006)</span>\n</h4>',
#  '<h4>\n<span class="unbold">40.</span>\nThe Usual Suspects\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">41.</span>\nThe Prestige\n<span class="unbold">(2006)</span>\n</h4>',
#  '<h4>\n<span class="unbold">42.</span>\nCasablanca\n<span class="unbold">(1942)</span>\n</h4>',
#  '<h4>\n<span class="unbold">43.</span>\nWhiplash\n<span class="unbold">(2014)</span>\n</h4>',
#  '<h4>\n<span class="unbold">44.</span>\nThe Intouchables\n<span class="unbold">(2011)</span>\n</h4>',
#  '<h4>\n<span class="unbold">45.</span>\nHarakiri\n<span class="unbold">(1962)</span>\n</h4>',
#  '<h4>\n<span class="unbold">46.</span>\nGrave of the Fireflies\n<span class="unbold">(1988)</span>\n</h4>',
#  '<h4>\n<span class="unbold">47.</span>\nModern Times\n<span class="unbold">(1936)</span>\n</h4>',
#  '<h4>\n<span class="unbold">48.</span>\nOnce Upon a Time in the West\n<span class="unbold">(1968)</span>\n</h4>',
#  '<h4>\n<span class="unbold">49.</span>\nRear Window\n<span class="unbold">(1954)</span>\n</h4>',
#  '<h4>\n<span class="unbold">50.</span>\nAlien\n<span class="unbold">(1979)</span>\n</h4>',
#  '<h4>\n<span class="unbold">51.</span>\nCity Lights\n<span class="unbold">(1931)</span>\n</h4>',
#  '<h4>\n<span class="unbold">52.</span>\nCinema Paradiso\n<span class="unbold">(1988)</span>\n</h4>',
#  '<h4>\n<span class="unbold">53.</span>\nApocalypse Now\n<span class="unbold">(1979)</span>\n</h4>',
#  '<h4>\n<span class="unbold">54.</span>\nMemento\n<span class="unbold">(2000)</span>\n</h4>',
#  '<h4>\n<span class="unbold">55.</span>\nIndiana Jones and the Raiders of the Lost Ark\n<span class="unbold">(1981)</span>\n</h4>',
#  '<h4>\n<span class="unbold">56.</span>\nTop Gun: Maverick\n<span class="unbold">(2022)</span>\n</h4>',
#  '<h4>\n<span class="unbold">57.</span>\nDjango Unchained\n<span class="unbold">(2012)</span>\n</h4>',
#  '<h4>\n<span class="unbold">58.</span>\nWALL·E\n<span class="unbold">(2008)</span>\n</h4>',
#  '<h4>\n<span class="unbold">59.</span>\nThe Lives of Others\n<span class="unbold">(2006)</span>\n</h4>',
#  '<h4>\n<span class="unbold">60.</span>\nSunset Blvd.\n<span class="unbold">(1950)</span>\n</h4>',
#  '<h4>\n<span class="unbold">61.</span>\nPaths of Glory\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">62.</span>\nThe Shining\n<span class="unbold">(1980)</span>\n</h4>',
#  '<h4>\n<span class="unbold">63.</span>\nThe Great Dictator\n<span class="unbold">(1940)</span>\n</h4>',
#  '<h4>\n<span class="unbold">64.</span>\nWitness for the Prosecution\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">65.</span>\nAvengers: Infinity War\n<span class="unbold">(2018)</span>\n</h4>',
#  '<h4>\n<span class="unbold">66.</span>\nAliens\n<span class="unbold">(1986)</span>\n</h4>',
#  '<h4>\n<span class="unbold">67.</span>\nAmerican Beauty\n<span class="unbold">(1999)</span>\n</h4>',
#  '<h4>\n<span class="unbold">68.</span>\nDr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb\n<span class="unbold">(1964)</span>\n</h4>',
#  '<h4>\n<span class="unbold">69.</span>\nSpider-Man: Into the Spider-Verse\n<span class="unbold">(2018)</span>\n</h4>',
#  '<h4>\n<span class="unbold">70.</span>\nThe Dark Knight Rises\n<span class="unbold">(2012)</span>\n</h4>',
#  '<h4>\n<span class="unbold">71.</span>\nOldboy\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">72.</span>\nJoker\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">73.</span>\nAmadeus\n<span class="unbold">(1984)</span>\n</h4>',
#  '<h4>\n<span class="unbold">74.</span>\nBraveheart\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">75.</span>\nToy Story\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">76.</span>\nCoco\n<span class="unbold">(2017)</span>\n</h4>',
#  '<h4>\n<span class="unbold">77.</span>\nInglourious Basterds\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">78.</span>\nThe Boat\n<span class="unbold">(1981)</span>\n</h4>',
#  '<h4>\n<span class="unbold">79.</span>\nPrincess Mononoke\n<span class="unbold">(1997)</span>\n</h4>',
#  '<h4>\n<span class="unbold">80.</span>\nAvengers: Endgame\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">81.</span>\nOnce Upon a Time in America\n<span class="unbold">(1984)</span>\n</h4>',
#  '<h4>\n<span class="unbold">82.</span>\nGood Will Hunting\n<span class="unbold">(1997)</span>\n</h4>',
#  '<h4>\n<span class="unbold">83.</span>\nYour Name.\n<span class="unbold">(2016)</span>\n</h4>',
#  '<h4>\n<span class="unbold">84.</span>\nRequiem for a Dream\n<span class="unbold">(2000)</span>\n</h4>',
#  '<h4>\n<span class="unbold">85.</span>\nToy Story 3\n<span class="unbold">(2010)</span>\n</h4>',
#  '<h4>\n<span class="unbold">86.</span>\nSingin\' in the Rain\n<span class="unbold">(1952)</span>\n</h4>',
#  '<h4>\n<span class="unbold">87.</span>\n3 Idiots\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">88.</span>\nStar Wars: Episode VI - Return of the Jedi\n<span class="unbold">(1983)</span>\n</h4>',
#  '<h4>\n<span class="unbold">89.</span>\nHigh and Low\n<span class="unbold">(1963)</span>\n</h4>',
#  '<h4>\n<span class="unbold">90.</span>\n2001: A Space Odyssey\n<span class="unbold">(1968)</span>\n</h4>',
#  '<h4>\n<span class="unbold">91.</span>\nEternal Sunshine of the Spotless Mind\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">92.</span>\nReservoir Dogs\n<span class="unbold">(1992)</span>\n</h4>',
#  '<h4>\n<span class="unbold">93.</span>\nCapernaum\n<span class="unbold">(2018)</span>\n</h4>',
#  '<h4>\n<span class="unbold">94.</span>\nLawrence of Arabia\n<span class="unbold">(1962)</span>\n</h4>',
#  '<h4>\n<span class="unbold">95.</span>\nCitizen Kane\n<span class="unbold">(1941)</span>\n</h4>',
#  '<h4>\n<span class="unbold">96.</span>\nThe Hunt\n<span class="unbold">(2012)</span>\n</h4>',
#  '<h4>\n<span class="unbold">97.</span>\nM\n<span class="unbold">(1931)</span>\n</h4>',
#  '<h4>\n<span class="unbold">98.</span>\nNorth by Northwest\n<span class="unbold">(1959)</span>\n</h4>',
#  '<h4>\n<span class="unbold">99.</span>\nCome and See\n<span class="unbold">(1985)</span>\n</h4>',
#  '<h4>\n<span class="unbold">100.</span>\nVertigo\n<span class="unbold">(1958)</span>\n</h4>',
#  '<h4>\n<span class="unbold">101.</span>\nAmélie\n<span class="unbold">(2001)</span>\n</h4>',
#  '<h4>\n<span class="unbold">102.</span>\nA Clockwork Orange\n<span class="unbold">(1971)</span>\n</h4>',
#  '<h4>\n<span class="unbold">103.</span>\nDouble Indemnity\n<span class="unbold">(1944)</span>\n</h4>',
#  '<h4>\n<span class="unbold">104.</span>\nFull Metal Jacket\n<span class="unbold">(1987)</span>\n</h4>',
#  '<h4>\n<span class="unbold">105.</span>\nThe Apartment\n<span class="unbold">(1960)</span>\n</h4>',
#  '<h4>\n<span class="unbold">106.</span>\nScarface\n<span class="unbold">(1983)</span>\n</h4>',
#  '<h4>\n<span class="unbold">107.</span>\nIkiru\n<span class="unbold">(1952)</span>\n</h4>',
#  '<h4>\n<span class="unbold">108.</span>\nThe Sting\n<span class="unbold">(1973)</span>\n</h4>',
#  '<h4>\n<span class="unbold">109.</span>\nTo Kill a Mockingbird\n<span class="unbold">(1962)</span>\n</h4>',
#  '<h4>\n<span class="unbold">110.</span>\nTaxi Driver\n<span class="unbold">(1976)</span>\n</h4>',
#  '<h4>\n<span class="unbold">111.</span>\nHeat\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">112.</span>\nUp\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">113.</span>\nL.A. Confidential\n<span class="unbold">(1997)</span>\n</h4>',
#  '<h4>\n<span class="unbold">114.</span>\nMetropolis\n<span class="unbold">(1927)</span>\n</h4>',
#  '<h4>\n<span class="unbold">115.</span>\nIncendies\n<span class="unbold">(2010)</span>\n</h4>',
#  '<h4>\n<span class="unbold">116.</span>\nA Separation\n<span class="unbold">(2011)</span>\n</h4>',
#  '<h4>\n<span class="unbold">117.</span>\nDie Hard\n<span class="unbold">(1988)</span>\n</h4>',
#  '<h4>\n<span class="unbold">118.</span>\nSnatch\n<span class="unbold">(2000)</span>\n</h4>',
#  '<h4>\n<span class="unbold">119.</span>\nIndiana Jones and the Last Crusade\n<span class="unbold">(1989)</span>\n</h4>',
#  '<h4>\n<span class="unbold">120.</span>\nBicycle Thieves\n<span class="unbold">(1948)</span>\n</h4>',
#  '<h4>\n<span class="unbold">121.</span>\nHamilton\n<span class="unbold">(2020)</span>\n</h4>',
#  '<h4>\n<span class="unbold">122.</span>\n1917\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">123.</span>\nLike Stars on Earth\n<span class="unbold">(2007)</span>\n</h4>',
#  '<h4>\n<span class="unbold">124.</span>\nDownfall\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">125.</span>\nFor a Few Dollars More\n<span class="unbold">(1965)</span>\n</h4>',
#  '<h4>\n<span class="unbold">126.</span>\nBatman Begins\n<span class="unbold">(2005)</span>\n</h4>',
#  '<h4>\n<span class="unbold">127.</span>\nDangal\n<span class="unbold">(2016)</span>\n</h4>',
#  '<h4>\n<span class="unbold">128.</span>\nThe Kid\n<span class="unbold">(1921)</span>\n</h4>',
#  '<h4>\n<span class="unbold">129.</span>\nSome Like It Hot\n<span class="unbold">(1959)</span>\n</h4>',
#  '<h4>\n<span class="unbold">130.</span>\nAll About Eve\n<span class="unbold">(1950)</span>\n</h4>',
#  '<h4>\n<span class="unbold">131.</span>\nThe Father\n<span class="unbold">(2020)</span>\n</h4>',
#  '<h4>\n<span class="unbold">132.</span>\nGreen Book\n<span class="unbold">(2018)</span>\n</h4>',
#  '<h4>\n<span class="unbold">133.</span>\nSpider-Man: No Way Home\n<span class="unbold">(2021)</span>\n</h4>',
#  '<h4>\n<span class="unbold">134.</span>\nThe Wolf of Wall Street\n<span class="unbold">(2013)</span>\n</h4>',
#  '<h4>\n<span class="unbold">135.</span>\nJudgment at Nuremberg\n<span class="unbold">(1961)</span>\n</h4>',
#  '<h4>\n<span class="unbold">136.</span>\nRan\n<span class="unbold">(1985)</span>\n</h4>',
#  '<h4>\n<span class="unbold">137.</span>\nCasino\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">138.</span>\nUnforgiven\n<span class="unbold">(1992)</span>\n</h4>',
#  '<h4>\n<span class="unbold">139.</span>\nPan\'s Labyrinth\n<span class="unbold">(2006)</span>\n</h4>',
#  '<h4>\n<span class="unbold">140.</span>\nThere Will Be Blood\n<span class="unbold">(2007)</span>\n</h4>',
#  '<h4>\n<span class="unbold">141.</span>\nThe Sixth Sense\n<span class="unbold">(1999)</span>\n</h4>',
#  '<h4>\n<span class="unbold">142.</span>\nThe Truman Show\n<span class="unbold">(1998)</span>\n</h4>',
#  '<h4>\n<span class="unbold">143.</span>\nA Beautiful Mind\n<span class="unbold">(2001)</span>\n</h4>',
#  '<h4>\n<span class="unbold">144.</span>\nMonty Python and the Holy Grail\n<span class="unbold">(1975)</span>\n</h4>',
#  '<h4>\n<span class="unbold">145.</span>\nYojimbo\n<span class="unbold">(1961)</span>\n</h4>',
#  '<h4>\n<span class="unbold">146.</span>\nThe Treasure of the Sierra Madre\n<span class="unbold">(1948)</span>\n</h4>',
#  '<h4>\n<span class="unbold">147.</span>\nShutter Island\n<span class="unbold">(2010)</span>\n</h4>',
#  '<h4>\n<span class="unbold">148.</span>\nJurassic Park\n<span class="unbold">(1993)</span>\n</h4>',
#  '<h4>\n<span class="unbold">149.</span>\nThe Great Escape\n<span class="unbold">(1963)</span>\n</h4>',
#  '<h4>\n<span class="unbold">150.</span>\nRashomon\n<span class="unbold">(1950)</span>\n</h4>',
#  '<h4>\n<span class="unbold">151.</span>\nKill Bill: Vol. 1\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">152.</span>\nNo Country for Old Men\n<span class="unbold">(2007)</span>\n</h4>',
#  '<h4>\n<span class="unbold">153.</span>\nFinding Nemo\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">154.</span>\nThe Elephant Man\n<span class="unbold">(1980)</span>\n</h4>',
#  '<h4>\n<span class="unbold">155.</span>\nChinatown\n<span class="unbold">(1974)</span>\n</h4>',
#  '<h4>\n<span class="unbold">156.</span>\nRaging Bull\n<span class="unbold">(1980)</span>\n</h4>',
#  '<h4>\n<span class="unbold">157.</span>\nThe Thing\n<span class="unbold">(1982)</span>\n</h4>',
#  '<h4>\n<span class="unbold">158.</span>\nGone with the Wind\n<span class="unbold">(1939)</span>\n</h4>',
#  '<h4>\n<span class="unbold">159.</span>\nV for Vendetta\n<span class="unbold">(2005)</span>\n</h4>',
#  '<h4>\n<span class="unbold">160.</span>\nInside Out\n<span class="unbold">(2015)</span>\n</h4>',
#  '<h4>\n<span class="unbold">161.</span>\nLock, Stock and Two Smoking Barrels\n<span class="unbold">(1998)</span>\n</h4>',
#  '<h4>\n<span class="unbold">162.</span>\nDial M for Murder\n<span class="unbold">(1954)</span>\n</h4>',
#  '<h4>\n<span class="unbold">163.</span>\nThe Secret in Their Eyes\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">164.</span>\nHowl\'s Moving Castle\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">165.</span>\nThe Bridge on the River Kwai\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">166.</span>\nThree Billboards Outside Ebbing, Missouri\n<span class="unbold">(2017)</span>\n</h4>',
#  '<h4>\n<span class="unbold">167.</span>\nTrainspotting\n<span class="unbold">(1996)</span>\n</h4>',
#  '<h4>\n<span class="unbold">168.</span>\nWarrior\n<span class="unbold">(2011)</span>\n</h4>',
#  '<h4>\n<span class="unbold">169.</span>\nGran Torino\n<span class="unbold">(2008)</span>\n</h4>',
#  '<h4>\n<span class="unbold">170.</span>\nFargo\n<span class="unbold">(1996)</span>\n</h4>',
#  '<h4>\n<span class="unbold">171.</span>\nPrisoners\n<span class="unbold">(2013)</span>\n</h4>',
#  '<h4>\n<span class="unbold">172.</span>\nMy Neighbor Totoro\n<span class="unbold">(1988)</span>\n</h4>',
#  '<h4>\n<span class="unbold">173.</span>\nMillion Dollar Baby\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">174.</span>\nCatch Me If You Can\n<span class="unbold">(2002)</span>\n</h4>',
#  '<h4>\n<span class="unbold">175.</span>\nThe Gold Rush\n<span class="unbold">(1925)</span>\n</h4>',
#  '<h4>\n<span class="unbold">176.</span>\nBlade Runner\n<span class="unbold">(1982)</span>\n</h4>',
#  '<h4>\n<span class="unbold">177.</span>\nEverything Everywhere All at Once\n<span class="unbold">(2022)</span>\n</h4>',
#  '<h4>\n<span class="unbold">178.</span>\nOn the Waterfront\n<span class="unbold">(1954)</span>\n</h4>',
#  '<h4>\n<span class="unbold">179.</span>\nChildren of Heaven\n<span class="unbold">(1997)</span>\n</h4>',
#  '<h4>\n<span class="unbold">180.</span>\nThe Third Man\n<span class="unbold">(1949)</span>\n</h4>',
#  '<h4>\n<span class="unbold">181.</span>\nBen-Hur\n<span class="unbold">(1959)</span>\n</h4>',
#  '<h4>\n<span class="unbold">182.</span>\nBefore Sunrise\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">183.</span>\n12 Years a Slave\n<span class="unbold">(2013)</span>\n</h4>',
#  '<h4>\n<span class="unbold">184.</span>\nWild Strawberries\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">185.</span>\nThe General\n<span class="unbold">(1926)</span>\n</h4>',
#  '<h4>\n<span class="unbold">186.</span>\nGone Girl\n<span class="unbold">(2014)</span>\n</h4>',
#  '<h4>\n<span class="unbold">187.</span>\nHarry Potter and the Deathly Hallows: Part 2\n<span class="unbold">(2011)</span>\n</h4>',
#  '<h4>\n<span class="unbold">188.</span>\nThe Deer Hunter\n<span class="unbold">(1978)</span>\n</h4>',
#  '<h4>\n<span class="unbold">189.</span>\nIn the Name of the Father\n<span class="unbold">(1993)</span>\n</h4>',
#  '<h4>\n<span class="unbold">190.</span>\nThe Grand Budapest Hotel\n<span class="unbold">(2014)</span>\n</h4>',
#  '<h4>\n<span class="unbold">191.</span>\nMr. Smith Goes to Washington\n<span class="unbold">(1939)</span>\n</h4>',
#  '<h4>\n<span class="unbold">192.</span>\nBarry Lyndon\n<span class="unbold">(1975)</span>\n</h4>',
#  '<h4>\n<span class="unbold">193.</span>\nThe Wages of Fear\n<span class="unbold">(1953)</span>\n</h4>',
#  '<h4>\n<span class="unbold">194.</span>\nSherlock Jr.\n<span class="unbold">(1924)</span>\n</h4>',
#  '<h4>\n<span class="unbold">195.</span>\nMemories of Murder\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">196.</span>\nHacksaw Ridge\n<span class="unbold">(2016)</span>\n</h4>',
#  '<h4>\n<span class="unbold">197.</span>\nKlaus\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">198.</span>\nWild Tales\n<span class="unbold">(2014)</span>\n</h4>',
#  '<h4>\n<span class="unbold">199.</span>\nThe Seventh Seal\n<span class="unbold">(1957)</span>\n</h4>',
#  '<h4>\n<span class="unbold">200.</span>\nRoom\n<span class="unbold">(2015)</span>\n</h4>',
#  '<h4>\n<span class="unbold">201.</span>\nMad Max: Fury Road\n<span class="unbold">(2015)</span>\n</h4>',
#  '<h4>\n<span class="unbold">202.</span>\nHow to Train Your Dragon\n<span class="unbold">(2010)</span>\n</h4>',
#  '<h4>\n<span class="unbold">203.</span>\nThe Big Lebowski\n<span class="unbold">(1998)</span>\n</h4>',
#  '<h4>\n<span class="unbold">204.</span>\nMary and Max\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">205.</span>\nMonsters, Inc.\n<span class="unbold">(2001)</span>\n</h4>',
#  '<h4>\n<span class="unbold">206.</span>\nJaws\n<span class="unbold">(1975)</span>\n</h4>',
#  '<h4>\n<span class="unbold">207.</span>\nTokyo Story\n<span class="unbold">(1953)</span>\n</h4>',
#  '<h4>\n<span class="unbold">208.</span>\nDead Poets Society\n<span class="unbold">(1989)</span>\n</h4>',
#  '<h4>\n<span class="unbold">209.</span>\nThe Passion of Joan of Arc\n<span class="unbold">(1928)</span>\n</h4>',
#  '<h4>\n<span class="unbold">210.</span>\nHotel Rwanda\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">211.</span>\nRocky\n<span class="unbold">(1976)</span>\n</h4>',
#  '<h4>\n<span class="unbold">212.</span>\nFord v Ferrari\n<span class="unbold">(2019)</span>\n</h4>',
#  '<h4>\n<span class="unbold">213.</span>\nPlatoon\n<span class="unbold">(1986)</span>\n</h4>',
#  '<h4>\n<span class="unbold">214.</span>\nPather Panchali\n<span class="unbold">(1955)</span>\n</h4>',
#  '<h4>\n<span class="unbold">215.</span>\nStand by Me\n<span class="unbold">(1986)</span>\n</h4>',
#  '<h4>\n<span class="unbold">216.</span>\nThe Terminator\n<span class="unbold">(1984)</span>\n</h4>',
#  '<h4>\n<span class="unbold">217.</span>\nSpotlight\n<span class="unbold">(2015)</span>\n</h4>',
#  '<h4>\n<span class="unbold">218.</span>\nRush\n<span class="unbold">(2013)</span>\n</h4>',
#  '<h4>\n<span class="unbold">219.</span>\nLogan\n<span class="unbold">(2017)</span>\n</h4>',
#  '<h4>\n<span class="unbold">220.</span>\nNetwork\n<span class="unbold">(1976)</span>\n</h4>',
#  '<h4>\n<span class="unbold">221.</span>\nInto the Wild\n<span class="unbold">(2007)</span>\n</h4>',
#  '<h4>\n<span class="unbold">222.</span>\nRatatouille\n<span class="unbold">(2007)</span>\n</h4>',
#  '<h4>\n<span class="unbold">223.</span>\nThe Wizard of Oz\n<span class="unbold">(1939)</span>\n</h4>',
#  '<h4>\n<span class="unbold">224.</span>\nGroundhog Day\n<span class="unbold">(1993)</span>\n</h4>',
#  '<h4>\n<span class="unbold">225.</span>\nBefore Sunset\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">226.</span>\nThe Exorcist\n<span class="unbold">(1973)</span>\n</h4>',
#  '<h4>\n<span class="unbold">227.</span>\nThe Best Years of Our Lives\n<span class="unbold">(1946)</span>\n</h4>',
#  '<h4>\n<span class="unbold">228.</span>\nThe Incredibles\n<span class="unbold">(2004)</span>\n</h4>',
#  '<h4>\n<span class="unbold">229.</span>\nTo Be or Not to Be\n<span class="unbold">(1942)</span>\n</h4>',
#  '<h4>\n<span class="unbold">230.</span>\nThe Grapes of Wrath\n<span class="unbold">(1940)</span>\n</h4>',
#  '<h4>\n<span class="unbold">231.</span>\nThe Battle of Algiers\n<span class="unbold">(1966)</span>\n</h4>',
#  '<h4>\n<span class="unbold">232.</span>\nRebecca\n<span class="unbold">(1940)</span>\n</h4>',
#  '<h4>\n<span class="unbold">233.</span>\nHachi: A Dog\'s Tale\n<span class="unbold">(2009)</span>\n</h4>',
#  '<h4>\n<span class="unbold">234.</span>\nCool Hand Luke\n<span class="unbold">(1967)</span>\n</h4>',
#  '<h4>\n<span class="unbold">235.</span>\nAmores perros\n<span class="unbold">(2000)</span>\n</h4>',
#  '<h4>\n<span class="unbold">236.</span>\nPirates of the Caribbean: The Curse of the Black Pearl\n<span class="unbold">(2003)</span>\n</h4>',
#  '<h4>\n<span class="unbold">237.</span>\nLa Haine\n<span class="unbold">(1995)</span>\n</h4>',
#  '<h4>\n<span class="unbold">238.</span>\nMy Father and My Son\n<span class="unbold">(2005)</span>\n</h4>',
#  '<h4>\n<span class="unbold">239.</span>\nThe 400 Blows\n<span class="unbold">(1959)</span>\n</h4>',
#  '<h4>\n<span class="unbold">240.</span>\nPersona\n<span class="unbold">(1966)</span>\n</h4>',
#  '<h4>\n<span class="unbold">241.</span>\nIt Happened One Night\n<span class="unbold">(1934)</span>\n</h4>',
#  '<h4>\n<span class="unbold">242.</span>\nThe Sound of Music\n<span class="unbold">(1965)</span>\n</h4>',
#  '<h4>\n<span class="unbold">243.</span>\nLife of Brian\n<span class="unbold">(1979)</span>\n</h4>',
#  '<h4>\n<span class="unbold">244.</span>\nThe Handmaiden\n<span class="unbold">(2016)</span>\n</h4>',
#  '<h4>\n<span class="unbold">245.</span>\nDersu Uzala\n<span class="unbold">(1975)</span>\n</h4>',
#  '<h4>\n<span class="unbold">246.</span>\nJai Bhim\n<span class="unbold">(2021)</span>\n</h4>',
#  '<h4>\n<span class="unbold">247.</span>\nAladdin\n<span class="unbold">(1992)</span>\n</h4>',
#  '<h4>\n<span class="unbold">248.</span>\nGandhi\n<span class="unbold">(1982)</span>\n</h4>',
#  '<h4>\n<span class="unbold">249.</span>\nThe Help\n<span class="unbold">(2011)</span>\n</h4>',
#  '<h4>\n<span class="unbold">250.</span>\nThe Iron Giant\n<span class="unbold">(1999)</span>\n</h4>']

# %%
len(sel.xpath(xpath_for_movienames).extract())
# Out:
# 250

# %%
xpath_for_movienames ='//h4/text()'

# %%
movies = sel.xpath(xpath_for_movienames).extract()

# %%
movies
# Out:
# ['\n',
#  '\nThe Shawshank Redemption\n',
#  '\n',
#  '\n',
#  '\nThe Godfather\n',
#  '\n',
#  '\n',
#  '\nThe Dark Knight\n',
#  '\n',
#  '\n',
#  '\nThe Godfather Part II\n',
#  '\n',
#  '\n',
#  '\n12 Angry Men\n',
#  '\n',
#  '\n',
#  "\nSchindler's List\n",
#  '\n',
#  '\n',
#  '\nThe Lord of the Rings: The Return of the King\n',
#  '\n',
#  '\n',
#  '\nPulp Fiction\n',
#  '\n',
#  '\n',
#  '\nThe Lord of the Rings: The Fellowship of the Ring\n',
#  '\n',
#  '\n',
#  '\nThe Good, the Bad and the Ugly\n',
#  '\n',
#  '\n',
#  '\nForrest Gump\n',
#  '\n',
#  '\n',
#  '\nFight Club\n',
#  '\n',
#  '\n',
#  '\nInception\n',
#  '\n',
#  '\n',
#  '\nThe Lord of the Rings: The Two Towers\n',
#  '\n',
#  '\n',
#  '\nStar Wars: Episode V - The Empire Strikes Back\n',
#  '\n',
#  '\n',
#  '\nThe Matrix\n',
#  '\n',
#  '\n',
#  '\nGoodfellas\n',
#  '\n',
#  '\n',
#  "\nOne Flew Over the Cuckoo's Nest\n",
#  '\n',
#  '\n',
#  '\nSe7en\n',
#  '\n',
#  '\n',
#  '\nSeven Samurai\n',
#  '\n',
#  '\n',
#  "\nIt's a Wonderful Life\n",
#  '\n',
#  '\n',
#  '\nThe Silence of the Lambs\n',
#  '\n',
#  '\n',
#  '\nCity of God\n',
#  '\n',
#  '\n',
#  '\nSaving Private Ryan\n',
#  '\n',
#  '\n',
#  '\nLife Is Beautiful\n',
#  '\n',
#  '\n',
#  '\nThe Green Mile\n',
#  '\n',
#  '\n',
#  '\nInterstellar\n',
#  '\n',
#  '\n',
#  '\nStar Wars\n',
#  '\n',
#  '\n',
#  '\nTerminator 2: Judgment Day\n',
#  '\n',
#  '\n',
#  '\nBack to the Future\n',
#  '\n',
#  '\n',
#  '\nSpirited Away\n',
#  '\n',
#  '\n',
#  '\nPsycho\n',
#  '\n',
#  '\n',
#  '\nThe Pianist\n',
#  '\n',
#  '\n',
#  '\nLéon: The Professional\n',
#  '\n',
#  '\n',
#  '\nParasite\n',
#  '\n',
#  '\n',
#  '\nThe Lion King\n',
#  '\n',
#  '\n',
#  '\nGladiator\n',
#  '\n',
#  '\n',
#  '\nAmerican History X\n',
#  '\n',
#  '\n',
#  '\nThe Departed\n',
#  '\n',
#  '\n',
#  '\nThe Usual Suspects\n',
#  '\n',
#  '\n',
#  '\nThe Prestige\n',
#  '\n',
#  '\n',
#  '\nCasablanca\n',
#  '\n',
#  '\n',
#  '\nWhiplash\n',
#  '\n',
#  '\n',
#  '\nThe Intouchables\n',
#  '\n',
#  '\n',
#  '\nHarakiri\n',
#  '\n',
#  '\n',
#  '\nGrave of the Fireflies\n',
#  '\n',
#  '\n',
#  '\nModern Times\n',
#  '\n',
#  '\n',
#  '\nOnce Upon a Time in the West\n',
#  '\n',
#  '\n',
#  '\nRear Window\n',
#  '\n',
#  '\n',
#  '\nAlien\n',
#  '\n',
#  '\n',
#  '\nCity Lights\n',
#  '\n',
#  '\n',
#  '\nCinema Paradiso\n',
#  '\n',
#  '\n',
#  '\nApocalypse Now\n',
#  '\n',
#  '\n',
#  '\nMemento\n',
#  '\n',
#  '\n',
#  '\nIndiana Jones and the Raiders of the Lost Ark\n',
#  '\n',
#  '\n',
#  '\nTop Gun: Maverick\n',
#  '\n',
#  '\n',
#  '\nDjango Unchained\n',
#  '\n',
#  '\n',
#  '\nWALL·E\n',
#  '\n',
#  '\n',
#  '\nThe Lives of Others\n',
#  '\n',
#  '\n',
#  '\nSunset Blvd.\n',
#  '\n',
#  '\n',
#  '\nPaths of Glory\n',
#  '\n',
#  '\n',
#  '\nThe Shining\n',
#  '\n',
#  '\n',
#  '\nThe Great Dictator\n',
#  '\n',
#  '\n',
#  '\nWitness for the Prosecution\n',
#  '\n',
#  '\n',
#  '\nAvengers: Infinity War\n',
#  '\n',
#  '\n',
#  '\nAliens\n',
#  '\n',
#  '\n',
#  '\nAmerican Beauty\n',
#  '\n',
#  '\n',
#  '\nDr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb\n',
#  '\n',
#  '\n',
#  '\nSpider-Man: Into the Spider-Verse\n',
#  '\n',
#  '\n',
#  '\nThe Dark Knight Rises\n',
#  '\n',
#  '\n',
#  '\nOldboy\n',
#  '\n',
#  '\n',
#  '\nJoker\n',
#  '\n',
#  '\n',
#  '\nAmadeus\n',
#  '\n',
#  '\n',
#  '\nBraveheart\n',
#  '\n',
#  '\n',
#  '\nToy Story\n',
#  '\n',
#  '\n',
#  '\nCoco\n',
#  '\n',
#  '\n',
#  '\nInglourious Basterds\n',
#  '\n',
#  '\n',
#  '\nThe Boat\n',
#  '\n',
#  '\n',
#  '\nPrincess Mononoke\n',
#  '\n',
#  '\n',
#  '\nAvengers: Endgame\n',
#  '\n',
#  '\n',
#  '\nOnce Upon a Time in America\n',
#  '\n',
#  '\n',
#  '\nGood Will Hunting\n',
#  '\n',
#  '\n',
#  '\nYour Name.\n',
#  '\n',
#  '\n',
#  '\nRequiem for a Dream\n',
#  '\n',
#  '\n',
#  '\nToy Story 3\n',
#  '\n',
#  '\n',
#  "\nSingin' in the Rain\n",
#  '\n',
#  '\n',
#  '\n3 Idiots\n',
#  '\n',
#  '\n',
#  '\nStar Wars: Episode VI - Return of the Jedi\n',
#  '\n',
#  '\n',
#  '\nHigh and Low\n',
#  '\n',
#  '\n',
#  '\n2001: A Space Odyssey\n',
#  '\n',
#  '\n',
#  '\nEternal Sunshine of the Spotless Mind\n',
#  '\n',
#  '\n',
#  '\nReservoir Dogs\n',
#  '\n',
#  '\n',
#  '\nCapernaum\n',
#  '\n',
#  '\n',
#  '\nLawrence of Arabia\n',
#  '\n',
#  '\n',
#  '\nCitizen Kane\n',
#  '\n',
#  '\n',
#  '\nThe Hunt\n',
#  '\n',
#  '\n',
#  '\nM\n',
#  '\n',
#  '\n',
#  '\nNorth by Northwest\n',
#  '\n',
#  '\n',
#  '\nCome and See\n',
#  '\n',
#  '\n',
#  '\nVertigo\n',
#  '\n',
#  '\n',
#  '\nAmélie\n',
#  '\n',
#  '\n',
#  '\nA Clockwork Orange\n',
#  '\n',
#  '\n',
#  '\nDouble Indemnity\n',
#  '\n',
#  '\n',
#  '\nFull Metal Jacket\n',
#  '\n',
#  '\n',
#  '\nThe Apartment\n',
#  '\n',
#  '\n',
#  '\nScarface\n',
#  '\n',
#  '\n',
#  '\nIkiru\n',
#  '\n',
#  '\n',
#  '\nThe Sting\n',
#  '\n',
#  '\n',
#  '\nTo Kill a Mockingbird\n',
#  '\n',
#  '\n',
#  '\nTaxi Driver\n',
#  '\n',
#  '\n',
#  '\nHeat\n',
#  '\n',
#  '\n',
#  '\nUp\n',
#  '\n',
#  '\n',
#  '\nL.A. Confidential\n',
#  '\n',
#  '\n',
#  '\nMetropolis\n',
#  '\n',
#  '\n',
#  '\nIncendies\n',
#  '\n',
#  '\n',
#  '\nA Separation\n',
#  '\n',
#  '\n',
#  '\nDie Hard\n',
#  '\n',
#  '\n',
#  '\nSnatch\n',
#  '\n',
#  '\n',
#  '\nIndiana Jones and the Last Crusade\n',
#  '\n',
#  '\n',
#  '\nBicycle Thieves\n',
#  '\n',
#  '\n',
#  '\nHamilton\n',
#  '\n',
#  '\n',
#  '\n1917\n',
#  '\n',
#  '\n',
#  '\nLike Stars on Earth\n',
#  '\n',
#  '\n',
#  '\nDownfall\n',
#  '\n',
#  '\n',
#  '\nFor a Few Dollars More\n',
#  '\n',
#  '\n',
#  '\nBatman Begins\n',
#  '\n',
#  '\n',
#  '\nDangal\n',
#  '\n',
#  '\n',
#  '\nThe Kid\n',
#  '\n',
#  '\n',
#  '\nSome Like It Hot\n',
#  '\n',
#  '\n',
#  '\nAll About Eve\n',
#  '\n',
#  '\n',
#  '\nThe Father\n',
#  '\n',
#  '\n',
#  '\nGreen Book\n',
#  '\n',
#  '\n',
#  '\nSpider-Man: No Way Home\n',
#  '\n',
#  '\n',
#  '\nThe Wolf of Wall Street\n',
#  '\n',
#  '\n',
#  '\nJudgment at Nuremberg\n',
#  '\n',
#  '\n',
#  '\nRan\n',
#  '\n',
#  '\n',
#  '\nCasino\n',
#  '\n',
#  '\n',
#  '\nUnforgiven\n',
#  '\n',
#  '\n',
#  "\nPan's Labyrinth\n",
#  '\n',
#  '\n',
#  '\nThere Will Be Blood\n',
#  '\n',
#  '\n',
#  '\nThe Sixth Sense\n',
#  '\n',
#  '\n',
#  '\nThe Truman Show\n',
#  '\n',
#  '\n',
#  '\nA Beautiful Mind\n',
#  '\n',
#  '\n',
#  '\nMonty Python and the Holy Grail\n',
#  '\n',
#  '\n',
#  '\nYojimbo\n',
#  '\n',
#  '\n',
#  '\nThe Treasure of the Sierra Madre\n',
#  '\n',
#  '\n',
#  '\nShutter Island\n',
#  '\n',
#  '\n',
#  '\nJurassic Park\n',
#  '\n',
#  '\n',
#  '\nThe Great Escape\n',
#  '\n',
#  '\n',
#  '\nRashomon\n',
#  '\n',
#  '\n',
#  '\nKill Bill: Vol. 1\n',
#  '\n',
#  '\n',
#  '\nNo Country for Old Men\n',
#  '\n',
#  '\n',
#  '\nFinding Nemo\n',
#  '\n',
#  '\n',
#  '\nThe Elephant Man\n',
#  '\n',
#  '\n',
#  '\nChinatown\n',
#  '\n',
#  '\n',
#  '\nRaging Bull\n',
#  '\n',
#  '\n',
#  '\nThe Thing\n',
#  '\n',
#  '\n',
#  '\nGone with the Wind\n',
#  '\n',
#  '\n',
#  '\nV for Vendetta\n',
#  '\n',
#  '\n',
#  '\nInside Out\n',
#  '\n',
#  '\n',
#  '\nLock, Stock and Two Smoking Barrels\n',
#  '\n',
#  '\n',
#  '\nDial M for Murder\n',
#  '\n',
#  '\n',
#  '\nThe Secret in Their Eyes\n',
#  '\n',
#  '\n',
#  "\nHowl's Moving Castle\n",
#  '\n',
#  '\n',
#  '\nThe Bridge on the River Kwai\n',
#  '\n',
#  '\n',
#  '\nThree Billboards Outside Ebbing, Missouri\n',
#  '\n',
#  '\n',
#  '\nTrainspotting\n',
#  '\n',
#  '\n',
#  '\nWarrior\n',
#  '\n',
#  '\n',
#  '\nGran Torino\n',
#  '\n',
#  '\n',
#  '\nFargo\n',
#  '\n',
#  '\n',
#  '\nPrisoners\n',
#  '\n',
#  '\n',
#  '\nMy Neighbor Totoro\n',
#  '\n',
#  '\n',
#  '\nMillion Dollar Baby\n',
#  '\n',
#  '\n',
#  '\nCatch Me If You Can\n',
#  '\n',
#  '\n',
#  '\nThe Gold Rush\n',
#  '\n',
#  '\n',
#  '\nBlade Runner\n',
#  '\n',
#  '\n',
#  '\nEverything Everywhere All at Once\n',
#  '\n',
#  '\n',
#  '\nOn the Waterfront\n',
#  '\n',
#  '\n',
#  '\nChildren of Heaven\n',
#  '\n',
#  '\n',
#  '\nThe Third Man\n',
#  '\n',
#  '\n',
#  '\nBen-Hur\n',
#  '\n',
#  '\n',
#  '\nBefore Sunrise\n',
#  '\n',
#  '\n',
#  '\n12 Years a Slave\n',
#  '\n',
#  '\n',
#  '\nWild Strawberries\n',
#  '\n',
#  '\n',
#  '\nThe General\n',
#  '\n',
#  '\n',
#  '\nGone Girl\n',
#  '\n',
#  '\n',
#  '\nHarry Potter and the Deathly Hallows: Part 2\n',
#  '\n',
#  '\n',
#  '\nThe Deer Hunter\n',
#  '\n',
#  '\n',
#  '\nIn the Name of the Father\n',
#  '\n',
#  '\n',
#  '\nThe Grand Budapest Hotel\n',
#  '\n',
#  '\n',
#  '\nMr. Smith Goes to Washington\n',
#  '\n',
#  '\n',
#  '\nBarry Lyndon\n',
#  '\n',
#  '\n',
#  '\nThe Wages of Fear\n',
#  '\n',
#  '\n',
#  '\nSherlock Jr.\n',
#  '\n',
#  '\n',
#  '\nMemories of Murder\n',
#  '\n',
#  '\n',
#  '\nHacksaw Ridge\n',
#  '\n',
#  '\n',
#  '\nKlaus\n',
#  '\n',
#  '\n',
#  '\nWild Tales\n',
#  '\n',
#  '\n',
#  '\nThe Seventh Seal\n',
#  '\n',
#  '\n',
#  '\nRoom\n',
#  '\n',
#  '\n',
#  '\nMad Max: Fury Road\n',
#  '\n',
#  '\n',
#  '\nHow to Train Your Dragon\n',
#  '\n',
#  '\n',
#  '\nThe Big Lebowski\n',
#  '\n',
#  '\n',
#  '\nMary and Max\n',
#  '\n',
#  '\n',
#  '\nMonsters, Inc.\n',
#  '\n',
#  '\n',
#  '\nJaws\n',
#  '\n',
#  '\n',
#  '\nTokyo Story\n',
#  '\n',
#  '\n',
#  '\nDead Poets Society\n',
#  '\n',
#  '\n',
#  '\nThe Passion of Joan of Arc\n',
#  '\n',
#  '\n',
#  '\nHotel Rwanda\n',
#  '\n',
#  '\n',
#  '\nRocky\n',
#  '\n',
#  '\n',
#  '\nFord v Ferrari\n',
#  '\n',
#  '\n',
#  '\nPlatoon\n',
#  '\n',
#  '\n',
#  '\nPather Panchali\n',
#  '\n',
#  '\n',
#  '\nStand by Me\n',
#  '\n',
#  '\n',
#  '\nThe Terminator\n',
#  '\n',
#  '\n',
#  '\nSpotlight\n',
#  '\n',
#  '\n',
#  '\nRush\n',
#  '\n',
#  '\n',
#  '\nLogan\n',
#  '\n',
#  '\n',
#  '\nNetwork\n',
#  '\n',
#  '\n',
#  '\nInto the Wild\n',
#  '\n',
#  '\n',
#  '\nRatatouille\n',
#  '\n',
#  '\n',
#  '\nThe Wizard of Oz\n',
#  '\n',
#  '\n',
#  '\nGroundhog Day\n',
#  '\n',
#  '\n',
#  '\nBefore Sunset\n',
#  '\n',
#  '\n',
#  '\nThe Exorcist\n',
#  '\n',
#  '\n',
#  '\nThe Best Years of Our Lives\n',
#  '\n',
#  '\n',
#  '\nThe Incredibles\n',
#  '\n',
#  '\n',
#  '\nTo Be or Not to Be\n',
#  '\n',
#  '\n',
#  '\nThe Grapes of Wrath\n',
#  '\n',
#  '\n',
#  '\nThe Battle of Algiers\n',
#  '\n',
#  '\n',
#  '\nRebecca\n',
#  '\n',
#  '\n',
#  "\nHachi: A Dog's Tale\n",
#  '\n',
#  '\n',
#  '\nCool Hand Luke\n',
#  '\n',
#  '\n',
#  '\nAmores perros\n',
#  '\n',
#  '\n',
#  '\nPirates of the Caribbean: The Curse of the Black Pearl\n',
#  '\n',
#  '\n',
#  '\nLa Haine\n',
#  '\n',
#  '\n',
#  '\nMy Father and My Son\n',
#  '\n',
#  '\n',
#  '\nThe 400 Blows\n',
#  '\n',
#  '\n',
#  '\nPersona\n',
#  '\n',
#  '\n',
#  '\nIt Happened One Night\n',
#  '\n',
#  '\n',
#  '\nThe Sound of Music\n',
#  '\n',
#  '\n',
#  '\nLife of Brian\n',
#  '\n',
#  '\n',
#  '\nThe Handmaiden\n',
#  '\n',
#  '\n',
#  '\nDersu Uzala\n',
#  '\n',
#  '\n',
#  '\nJai Bhim\n',
#  '\n',
#  '\n',
#  '\nAladdin\n',
#  '\n',
#  '\n',
#  '\nGandhi\n',
#  '\n',
#  '\n',
#  '\nThe Help\n',
#  '\n',
#  '\n',
#  '\nThe Iron Giant\n',
#  '\n']

# %% [markdown]
# #### Clean your text with strip

# %%
movie_list=[]
for string in movies:
    cleaned_string = string.strip()
    if cleaned_string != '':
        movie_list.append(cleaned_string)
    
print(movie_list)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', "Schindler's List", 'The Lord of the Rings: The Return of the King', 'Pulp Fiction', 'The Lord of the Rings: The Fellowship of the Ring', 'The Good, the Bad and the Ugly', 'Forrest Gump', 'Fight Club', 'Inception', 'The Lord of the Rings: The Two Towers', 'Star Wars: Episode V - The Empire Strikes Back', 'The Matrix', 'Goodfellas', "One Flew Over the Cuckoo's Nest", 'Se7en', 'Seven Samurai', "It's a Wonderful Life", 'The Silence of the Lambs', 'City of God', 'Saving Private Ryan', 'Life Is Beautiful', 'The Green Mile', 'Interstellar', 'Star Wars', 'Terminator 2: Judgment Day', 'Back to the Future', 'Spirited Away', 'Psycho', 'The Pianist', 'Léon: The Professional', 'Parasite', 'The Lion King', 'Gladiator', 'American History X', 'The Departed', 'The Usual Suspects', 'The Prestige', 'Casablanca', 'Whiplash', 'The Intouchables', 'Harakiri', 'Grave of the Fireflies', 'Modern Times', 'Once Upon a Time in the West', 'Rear Window', 'Alien', 'City Lights', 'Cinema Paradiso', 'Apocalypse Now', 'Memento', 'Indiana Jones and the Raiders of the Lost Ark', 'Top Gun: Maverick', 'Django Unchained', 'WALL·E', 'The Lives of Others', 'Sunset Blvd.', 'Paths of Glory', 'The Shining', 'The Great Dictator', 'Witness for the Prosecution', 'Avengers: Infinity War', 'Aliens', 'American Beauty', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Spider-Man: Into the Spider-Verse', 'The Dark Knight Rises', 'Oldboy', 'Joker', 'Amadeus', 'Braveheart', 'Toy Story', 'Coco', 'Inglourious Basterds', 'The Boat', 'Princess Mononoke', 'Avengers: Endgame', 'Once Upon a Time in America', 'Good Will Hunting', 'Your Name.', 'Requiem for a Dream', 'Toy Story 3', "Singin' in the Rain", '3 Idiots', 'Star Wars: Episode VI - Return of the Jedi', 'High and Low', '2001: A Space Odyssey', 'Eternal Sunshine of the Spotless Mind', 'Reservoir Dogs', 'Capernaum', 'Lawrence of Arabia', 'Citizen Kane', 'The Hunt', 'M', 'North by Northwest', 'Come and See', 'Vertigo', 'Amélie', 'A Clockwork Orange', 'Double Indemnity', 'Full Metal Jacket', 'The Apartment', 'Scarface', 'Ikiru', 'The Sting', 'To Kill a Mockingbird', 'Taxi Driver', 'Heat', 'Up', 'L.A. Confidential', 'Metropolis', 'Incendies', 'A Separation', 'Die Hard', 'Snatch', 'Indiana Jones and the Last Crusade', 'Bicycle Thieves', 'Hamilton', '1917', 'Like Stars on Earth', 'Downfall', 'For a Few Dollars More', 'Batman Begins', 'Dangal', 'The Kid', 'Some Like It Hot', 'All About Eve', 'The Father', 'Green Book', 'Spider-Man: No Way Home', 'The Wolf of Wall Street', 'Judgment at Nuremberg', 'Ran', 'Casino', 'Unforgiven', "Pan's Labyrinth", 'There Will Be Blood', 'The Sixth Sense', 'The Truman Show', 'A Beautiful Mind', 'Monty Python and the Holy Grail', 'Yojimbo', 'The Treasure of the Sierra Madre', 'Shutter Island', 'Jurassic Park', 'The Great Escape', 'Rashomon', 'Kill Bill: Vol. 1', 'No Country for Old Men', 'Finding Nemo', 'The Elephant Man', 'Chinatown', 'Raging Bull', 'The Thing', 'Gone with the Wind', 'V for Vendetta', 'Inside Out', 'Lock, Stock and Two Smoking Barrels', 'Dial M for Murder', 'The Secret in Their Eyes', "Howl's Moving Castle", 'The Bridge on the River Kwai', 'Three Billboards Outside Ebbing, Missouri', 'Trainspotting', 'Warrior', 'Gran Torino', 'Fargo', 'Prisoners', 'My Neighbor Totoro', 'Million Dollar Baby', 'Catch Me If You Can', 'The Gold Rush', 'Blade Runner', 'Everything Everywhere All at Once', 'On the Waterfront', 'Children of Heaven', 'The Third Man', 'Ben-Hur', 'Before Sunrise', '12 Years a Slave', 'Wild Strawberries', 'The General', 'Gone Girl', 'Harry Potter and the Deathly Hallows: Part 2', 'The Deer Hunter', 'In the Name of the Father', 'The Grand Budapest Hotel', 'Mr. Smith Goes to Washington', 'Barry Lyndon', 'The Wages of Fear', 'Sherlock Jr.', 'Memories of Murder', 'Hacksaw Ridge', 'Klaus', 'Wild Tales', 'The Seventh Seal', 'Room', 'Mad Max: Fury Road', 'How to Tra ...

# %% [markdown]
# #### A brief break: How does strip function work?

# %%
string = '  xoxo love xoxo   '

# Leading and trailing whitespaces are removed
print(string.strip())

# All <whitespace>,x,o,e characters in the left
# and right of string are removed
print(string.strip(' xoe'))

# Argument doesn't contain space
# No characters are removed.
print(string.strip('stx'))

string = 'android is awesome'
print(string.strip('an'))
# Out:
# xoxo love xoxo
# lov
#   xoxo love xoxo
# droid is awesome

# %%
len(movie_list)
# Out:
# 250

# %% [markdown]
# #### Extracting the order and year of movies

# %%
xpath_for_movieorder ='//h4/span[1]/text()'
movie_order = sel.xpath(xpath_for_movieorder).extract()

# %%
xpath_for_moviedates ='//h4/span[2]/text()'
movie_date = sel.xpath(xpath_for_moviedates).extract()

# %% [markdown]
# ##### Copied Xpaths for the first four movies:
#
# //*[@id="chart-content"]/div[1]/div[1]/div/a
#
# //*[@id="chart-content"]/div[1]/div[2]/div/a
#
# //*[@id="chart-content"]/div[2]/div[1]/div/a
#
# //*[@id="chart-content"]/div[2]/div[2]/div/a
#
# …

# %% [markdown]
# #### Movie links

# %%
xpath_for_movielink = '//*[@id="chart-content"]/div/div/div/a/@href'
movie_link = sel.xpath(xpath_for_movielink).extract()

# %%
len(movie_link)
# Out:
# 250

# %%
movie_link
# Out:
# ['/title/tt0111161/',
#  '/title/tt0068646/',
#  '/title/tt0468569/',
#  '/title/tt0071562/',
#  '/title/tt0050083/',
#  '/title/tt0108052/',
#  '/title/tt0167260/',
#  '/title/tt0110912/',
#  '/title/tt0120737/',
#  '/title/tt0060196/',
#  '/title/tt0109830/',
#  '/title/tt0137523/',
#  '/title/tt1375666/',
#  '/title/tt0167261/',
#  '/title/tt0080684/',
#  '/title/tt0133093/',
#  '/title/tt0099685/',
#  '/title/tt0073486/',
#  '/title/tt0114369/',
#  '/title/tt0047478/',
#  '/title/tt0038650/',
#  '/title/tt0102926/',
#  '/title/tt0317248/',
#  '/title/tt0120815/',
#  '/title/tt0118799/',
#  '/title/tt0120689/',
#  '/title/tt0816692/',
#  '/title/tt0076759/',
#  '/title/tt0103064/',
#  '/title/tt0088763/',
#  '/title/tt0245429/',
#  '/title/tt0054215/',
#  '/title/tt0253474/',
#  '/title/tt0110413/',
#  '/title/tt6751668/',
#  '/title/tt0110357/',
#  '/title/tt0172495/',
#  '/title/tt0120586/',
#  '/title/tt0407887/',
#  '/title/tt0114814/',
#  '/title/tt0482571/',
#  '/title/tt0034583/',
#  '/title/tt2582802/',
#  '/title/tt1675434/',
#  '/title/tt0056058/',
#  '/title/tt0095327/',
#  '/title/tt0027977/',
#  '/title/tt0064116/',
#  '/title/tt0047396/',
#  '/title/tt0078748/',
#  '/title/tt0021749/',
#  '/title/tt0095765/',
#  '/title/tt0078788/',
#  '/title/tt0209144/',
#  '/title/tt0082971/',
#  '/title/tt1745960/',
#  '/title/tt1853728/',
#  '/title/tt0910970/',
#  '/title/tt0405094/',
#  '/title/tt0043014/',
#  '/title/tt0050825/',
#  '/title/tt0081505/',
#  '/title/tt0032553/',
#  '/title/tt0051201/',
#  '/title/tt4154756/',
#  '/title/tt0090605/',
#  '/title/tt0169547/',
#  '/title/tt0057012/',
#  '/title/tt4633694/',
#  '/title/tt1345836/',
#  '/title/tt0364569/',
#  '/title/tt7286456/',
#  '/title/tt0086879/',
#  '/title/tt0112573/',
#  '/title/tt0114709/',
#  '/title/tt2380307/',
#  '/title/tt0361748/',
#  '/title/tt0082096/',
#  '/title/tt0119698/',
#  '/title/tt4154796/',
#  '/title/tt0087843/',
#  '/title/tt0119217/',
#  '/title/tt5311514/',
#  '/title/tt0180093/',
#  '/title/tt0435761/',
#  '/title/tt0045152/',
#  '/title/tt1187043/',
#  '/title/tt0086190/',
#  '/title/tt0057565/',
#  '/title/tt0062622/',
#  '/title/tt0338013/',
#  '/title/tt0105236/',
#  '/title/tt8267604/',
#  '/title/tt0056172/',
#  '/title/tt0033467/',
#  '/title/tt2106476/',
#  '/title/tt0022100/',
#  '/title/tt0053125/',
#  '/title/tt0091251/',
#  '/title/tt0052357/',
#  '/title/tt0211915/',
#  '/title/tt0066921/',
#  '/title/tt0036775/',
#  '/title/tt0093058/',
#  '/title/tt0053604/',
#  '/title/tt0086250/',
#  '/title/tt0044741/',
#  '/title/tt0070735/',
#  '/title/tt0056592/',
#  '/title/tt0075314/',
#  '/title/tt0113277/',
#  '/title/tt1049413/',
#  '/title/tt0119488/',
#  '/title/tt0017136/',
#  '/title/tt1255953/',
#  '/title/tt1832382/',
#  '/title/tt0095016/',
#  '/title/tt0208092/',
#  '/title/tt0097576/',
#  '/title/tt0040522/',
#  '/title/tt8503618/',
#  '/title/tt8579674/',
#  '/title/tt0986264/',
#  '/title/tt0363163/',
#  '/title/tt0059578/',
#  '/title/tt0372784/',
#  '/title/tt5074352/',
#  '/title/tt0012349/',
#  '/title/tt0053291/',
#  '/title/tt0042192/',
#  '/title/tt10272386/',
#  '/title/tt6966692/',
#  '/title/tt10872600/',
#  '/title/tt0993846/',
#  '/title/tt0055031/',
#  '/title/tt0089881/',
#  '/title/tt0112641/',
#  '/title/tt0105695/',
#  '/title/tt0457430/',
#  '/title/tt0469494/',
#  '/title/tt0167404/',
#  '/title/tt0120382/',
#  '/title/tt0268978/',
#  '/title/tt0071853/',
#  '/title/tt0055630/',
#  '/title/tt0040897/',
#  '/title/tt1130884/',
#  '/title/tt0107290/',
#  '/title/tt0057115/',
#  '/title/tt0042876/',
#  '/title/tt0266697/',
#  '/title/tt0477348/',
#  '/title/tt0266543/',
#  '/title/tt0080678/',
#  '/title/tt0071315/',
#  '/title/tt0081398/',
#  '/title/tt0084787/',
#  '/title/tt0031381/',
#  '/title/tt0434409/',
#  '/title/tt2096673/',
#  '/title/tt0120735/',
#  '/title/tt0046912/',
#  '/title/tt1305806/',
#  '/title/tt0347149/',
#  '/title/tt0050212/',
#  '/title/tt5027774/',
#  '/title/tt0117951/',
#  '/title/tt1291584/',
#  '/title/tt1205489/',
#  '/title/tt0116282/',
#  '/title/tt1392214/',
#  '/title/tt0096283/',
#  '/title/tt0405159/',
#  '/title/tt0264464/',
#  '/title/tt0015864/',
#  '/title/tt0083658/',
#  '/title/tt6710474/',
#  '/title/tt0047296/',
#  '/title/tt0118849/',
#  '/title/tt0041959/',
#  '/title/tt0052618/',
#  '/title/tt0112471/',
#  '/title/tt2024544/',
#  '/title/tt0050986/',
#  '/title/tt0017925/',
#  '/title/tt2267998/',
#  '/title/tt1201607/',
#  '/title/tt0077416/',
#  '/title/tt0107207/',
#  '/title/tt2278388/',
#  '/title/tt0031679/',
#  '/title/tt0072684/',
#  '/title/tt0046268/',
#  '/title/tt0015324/',
#  '/title/tt0353969/',
#  '/title/tt2119532/',
#  '/title/tt4729430/',
#  '/title/tt3011894/',
#  '/title/tt0050976/',
#  '/title/tt3170832/',
#  '/title/tt1392190/',
#  '/title/tt0892769/',
#  '/title/tt0118715/',
#  '/title/tt0978762/',
#  '/title/tt0198781/',
#  '/title/tt0073195/',
#  '/title/tt0046438/',
#  '/title/tt0097165/',
#  '/title/tt0019254/',
#  '/title/tt0395169/',
#  '/title/tt0075148/',
#  '/title/tt1950186/',
#  '/title/tt0091763/',
#  '/title/tt0048473/',
#  '/title/tt0092005/',
#  '/title/tt0088247/',
#  '/title/tt1895587/',
#  '/title/tt1979320/',
#  '/title/tt3315342/',
#  '/title/tt0074958/',
#  '/title/tt0758758/',
#  '/title/tt0382932/',
#  '/title/tt0032138/',
#  '/title/tt0107048/',
#  '/title/tt0381681/',
#  '/title/tt0070047/',
#  '/title/tt0036868/',
#  '/title/tt0317705/',
#  '/title/tt0035446/',
#  '/title/tt0032551/',
#  '/title/tt0058946/',
#  '/title/tt0032976/',
#  '/title/tt1028532/',
#  '/title/tt0061512/',
#  '/title/tt0245712/',
#  '/title/tt0325980/',
#  '/title/tt0113247/',
#  '/title/tt0476735/',
#  '/title/tt0053198/',
#  '/title/tt0060827/',
#  '/title/tt0025316/',
#  '/title/tt0059742/',
#  '/title/tt0079470/',
#  '/title/tt4016934/',
#  '/title/tt0071411/',
#  '/title/tt15097216/',
#  '/title/tt0103639/',
#  '/title/tt0083987/',
#  '/title/tt1454029/',
#  '/title/tt0129167/']

# %% [markdown]
# Shared objects are partial, let's figure this our

# %%
first_part_url = 'https://m.imdb.com'
last_part_url = '?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1'

# %%
movie_link_merged = []

for i in movie_link:
    link = first_part_url + i + last_part_url
    movie_link_merged.append(link)

# %%
len(movie_link_merged)
# Out:
# 250

# %% [markdown]
# #### Let's store what we downloaded

# %%
dictimdb = {'movie_order':movie_order, 'movie_date':movie_date, 'movie_list':movie_list, 'movie_link_merged': movie_link_merged}

# %%
data_imdb = pd.DataFrame(dictimdb)

# %%
data_imdb['movie_link_merged'][0]
# Out:
# 'https://m.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1'

# %% [markdown]
# #### Can we go further?
#
# Let's find out players of these famous movies:

# %%
url = data_imdb['movie_link_merged'][0]

# %%
html = requests.get(url).content

sel = Selector(text = html)

print( "You have found: ", len(sel.xpath('//*')))
# Out:
# 2022-08-25 16:45:17 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:45:20 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None
# You have found:  2884

# %% [markdown]
# ##### Copied Xpaths for the first four players:
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/div[2]/div[2]/div[1]/div[2]/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/div[2]/div[2]/div[2]/div[2]/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/div[2]/div[2]/div[3]/div[2]/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/div[2]/div[2]/div[4]/div[2]/a

# %%
xpath_for_movieplayers ='//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[4]/div[2]/div[2]/div/div[2]/a/text()'
movie_players_first_movie = sel.xpath(xpath_for_movieplayers).extract()

# %%
movie_players_first_movie
# Out:
# ['Tim Robbins',
#  'Morgan Freeman',
#  'Bob Gunton',
#  'William Sadler',
#  'Clancy Brown',
#  'Gil Bellows',
#  'Mark Rolston',
#  'James Whitmore',
#  'Jeffrey DeMunn',
#  'Larry Brandenburg',
#  'Neil Giuntoli',
#  'Brian Libby',
#  'David Proval',
#  'Joseph Ragno',
#  'Jude Ciccolella',
#  'Paul McCrane',
#  'Renee Blaine',
#  'Scott Mann']

# %%
players_list=[]

# %%
for i in range(5):
    url = data_imdb['movie_link_merged'][i]
    html = requests.get(url).content
    sel = Selector(text = html)
    movie_players = sel.xpath(xpath_for_movieplayers).extract()
    players_list.append(movie_players)
# Out:
# 2022-08-25 16:52:37 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:52:38 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None
# 2022-08-25 16:52:38 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:52:39 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None
# 2022-08-25 16:52:39 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:52:40 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0468569/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None
# 2022-08-25 16:52:41 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:52:42 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None
# 2022-08-25 16:52:42 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): m.imdb.com:443
# 2022-08-25 16:52:44 [urllib3.connectionpool] DEBUG: https://m.imdb.com:443 "GET /title/tt0050083/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=df09bbba-7a44-41c0-bc85-426ba05a5574&pf_rd_r=R9N3Q0473JZET8YH4S2A&pf_rd_s=top-1&pf_rd_t=15506&pf_rd_i=top&ref_=m_chttp_tt_1 HTTP/1.1" 200 None

# %%
players_list[4]
# Out:
# ['Henry Fonda',
#  'Lee J. Cobb',
#  'Martin Balsam',
#  'John Fiedler',
#  'E.G. Marshall',
#  'Jack Klugman',
#  'Edward Binns',
#  'Jack Warden',
#  'Joseph Sweeney',
#  'Ed Begley',
#  'George Voskovec',
#  'Robert Webber',
#  'Rudy Bond',
#  'Tom Gorman',
#  'James Kelly',
#  'Billy Nelson',
#  'John Savoca',
#  'Walter Stocker']
